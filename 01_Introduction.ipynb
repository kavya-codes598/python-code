# %% [markdown]
# # Introduction to Python

# %% [markdown]
#   ### 1. What is Python?
#  Python is a high-level, interpreted, and easy to use programming language ()

# %% [markdown]
# ### Features of Python
# - Easy to use
# - Simple syntax
# - Open source
# - Platform independent
# - Large community support

# %% [markdown]
# ### First Python Program

# %%
print("Hello World")
# Out:
# Hello Word

# %% [markdown]
# ### Applications of Python

# %% [markdown]
# - Web Development
# - Game Development
# - Machine Learning
# - Automation
# - Data Science
